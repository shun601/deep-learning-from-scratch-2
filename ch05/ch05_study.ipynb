# %% [markdown]
# ## 5.3 RNNの実装

# %% [markdown]
# ## 5.3.1 RNNレイヤの実装

# %%
import sys
sys.path.append('..')
import numpy as np

# %%
class RNN(object):
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx) , np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
        
    def forward(self, x, h_prev):
        Wx, Wh, b = self.paramsqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqaaaaaaaaaaaaaaaaaaaaaaaaaaaaa444444444444444444444444
        t = np.dot(h_prev, Wh) + np.dot(x, Wx) + b
        h_next = np.tanh(t)
        
        self.cache = (x, h_prev, h_next)
        return h_next
    
    def backward(self, dh_next):
        Wx, Wh, b = self.params
        x, h_prev, h_next = self.cache
        
        dt = dh_next * (1 - h_next ** 2)
        db = np.sum(dt, axis=0)
        dWh = np.dot(h_prev.T, dt)
        dh_prev = np.dot(dt, Wh.T)
        dWx = np.dot(x.T, dt)
        dx = np.dot(dt, Wx.T)
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dx, dh_prev

# %% [markdown]
# ## 5.3.2 Time RNNレイヤの実装

# %%
class TimeRNN(object):
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        
        self.h, self.dh = None, None
        self.stateful = stateful
        
    def set_state(self, h):
        self.h = h
        
    def reset_state(self):
        self.h = None
        
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        D, H = Wx.shape
        
        self.layers = []
        hs = np.empty((N, T, H), dtype='f')
        
        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
            
        for t in range(T):
            layer = RNN(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layer.append(layer)
            
        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape
        
        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh) # 合算した勾配
            dxs[:, t, :] = dx
            
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
                
        for i , grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        
        return dxs

# %%
reversed?
# Out:
# Init signature: reversed(sequence, /)
# Docstring:      Return a reverse iterator over the values of the given sequence.
# Type:           type
# Subclasses:

# %%
for i in reversed(range(5)):
    print(i)
# Out:
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ## 5.4 時系列データを扱うレイヤの実装

# %% [markdown]
# ## 5.5.1 RNNLMの実装

# %%
import sys
sys.path.append('..')
import numpy as np
from common.time_layers import *

class SimpleRnnlm(object):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        # 重みの初期化
        embed_W = (rn(V, D) / 100).astype('f')
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        rnn_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        # レイヤの作成
        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.run_layer = self.layer[1]
        
        # 全ての重みと勾配をリストにまとめる
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
            loss = self.loss_layer.forward(xs, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return out
    
    def reset_state(self):
        self.rnn_layer.reset_state()

# %% [markdown]
# ## 5.5.3 RNNLMの学習コード

# %%
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import SGD
from dataset import ptb
from simple_rnnlm import SimpleRnnlm

# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100 # RNNの隠れ状態ベクトルの要素数
time_size = 5
lr = 0.1
max_epoch = 1000

# 学習データの読み込み(データセットを小さくする)
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]  # 入力
ts = corpus[1:] # 出力(教師ラベル)
data_size = len(xs)
print(f'corpus size:{corpus_size}, vocablary_size:{vocab_size}')

# 学習時に使用する変数
max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

# modelの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

# ミニバッチの各サンプルの読み込み開始位置を計算
jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        # ミニバッチの取得
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset * time_idx) % data_size]
            time_idx += 1
        
        # 勾配を求め、パラメータを更新
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1
        
    # epoch毎にパープレキシティの評価
    ppl = np.exp(total_loss / loss_count)
    print(f'| epoch {epoch+1} | perplexity {ppl:.2f}')
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0
# Out:
# corpus size:1000, vocablary_size:418
# | epoch 1 | perplexity 277.83
# | epoch 2 | perplexity 120.62
# | epoch 3 | perplexity 87.50
# | epoch 4 | perplexity 73.93
# | epoch 5 | perplexity 69.70
# | epoch 6 | perplexity 65.28
# | epoch 7 | perplexity 61.28
# | epoch 8 | perplexity 61.89
# | epoch 9 | perplexity 61.53
# | epoch 10 | perplexity 61.31
# | epoch 11 | perplexity 60.06
# | epoch 12 | perplexity 60.93
# | epoch 13 | perplexity 58.85
# | epoch 14 | perplexity 57.31
# | epoch 15 | perplexity 59.08
# | epoch 16 | perplexity 59.05
# | epoch 17 | perplexity 59.69
# | epoch 18 | perplexity 58.44
# | epoch 19 | perplexity 59.46
# | epoch 20 | perplexity 57.80
# | epoch 21 | perplexity 56.71
# | epoch 22 | perplexity 57.98
# | epoch 23 | perplexity 58.27
# | epoch 24 | perplexity 59.25
# | epoch 25 | perplexity 57.93
# | epoch 26 | perplexity 58.64
# | epoch 27 | perplexity 57.49
# | epoch 28 | perplexity 55.95
# | epoch 29 | perplexity 57.75
# | epoch 30 | perplexity 58.29
# | epoch 31 | perplexity 59.14
# | epoch 32 | perplexity 57.25
# | epoch 33 | perplexity 58.34
# | epoch 34 | perplexity 57.17
# | epoch 35 | perplexity 55.74
# | epoch 36 | perplexity 57.91
# | epoch 37 | perplexity 58.56
# | epoch 38 | perplexity 57.69
# | epoch 39 | perplexity 57.26
# | epoch 40 | perplexity 57.78
# | epoch 41 | perplexity 57.18
# | epoch 42 | perplexity 56.20
# | epoch 43 | perplexity 57.56
# | epoch 44 | perplexity 57.68
# | epoch 45 | perplexity 57.94
# | epoch 46 | perplexity 56.77
# | epoch 47 | perplexity 57.83
# | epoch 48 | perplexity 57.08
# | epoch 49 | perplexity 55.94
# | epoch 50 | perplexity 57.18
# | epoch 51 | perplexity 57.75
# | epoch 52 | perplexity 57.80
# | epoch 53 | perplexity 56.48
# | epoch 54 | perplexity 57.97
# | epoch 55 | perplexity 56.35
# | epoch 56 | perplexity 55.84
# | epoch 57 | perplexity 57.12
# | epoch 58 | perplexity 57.60
# | epoch 59 | perplexity 57.45
# | epoch 60 | perplexity 57.08
# | epoch 61 | perplexity 57.67
# | epoch 62 | perplexity 55.62
# | epoch 63 | perplexity 56.17
# | epoch 64 | perplexity 56.90
# | epoch 65 | perplexity 57.19
# | epoch 66 | perplexity 57.78
# | epoch 67 | perplexity 56.51
# | epoch 68 | perplexity 57.69
# | epoch 69 | perplexity 55.51
# | epoch 70 | perplexity 55.96
# | epoch 71 | perplexity 56.93
# | epoch 72 | perplexity 57.48
# | epoch 73 | perplexity 56.94
# | epoch 74 | perplexity 57.38
# | epoch 75 | perplexity 56.85
# | epoch 76 | perplexity 54.75
# | epoch 77 | perplexity 56.58
# | epoch 78 | perplexity 57.26
# | epoch 79 | perplexity 56.64
# | epoch 80 | perplexity 56.70
# | epoch 81 | perplexity 57.74
# | epoch 82 | perplexity 56.48
# | epoch 83 | perplexity 54.55
# | epoch 84 | perplexity 56.98
# | epoch 85 | perplexity 56.85
# | epoch 86 | perplexity 56.91
# | epoch 87 | perplexity 56.55
# | epoch 88 | perplexity 57.21
# | epoch 89 | perplexity 56.46
# | epoch 90 | perplexity 54.51
# | epoch 91 | perplexity 56.57
# | epoch 92 | perplexity 56.66
# | epoch 93 | perplexity 57.52
# | epoch 94 | perplexity 55.72
# | epoch 95 | perplexity 57.55
# | epoch 96 | perplexity 56.56
# | epoch 97 | perplexity 53.95
# | epoch 98 | perplexity 56.42
# | epoch 99 | perplexity 57.00
# | epoch 100 | perplexity 56.98
# | epoch 101 | perplexity 55.79
# | epoch 102 | perplexity 57.70
# | epoch 103 | perplexity 55.98
# | epoch 104 | perplexity 54.01
# | epoch 105 | perplexity 56.78
# | epoch 106 | perplexity 56.50
# | epoch 107 | perplexity 57.08
# | epoch 108 | perplexity 55.97
# | epoch 109 | perplexity 57.23
# | epoch 110 | perplexity 55.79
# | epoch 111 | perplexity 54.99
# | epoch 112 | perplexity 55.41
# | epoch 113 | perplexity 56.61
# | epoch 114 | perplexity 56.79
# | epoch 115 | perplexity 56.10
# | epoch 116 | perplexity 57.00
# | epoch 117 | perplexity 55.92
# | epoch 118 | perplexity 54.59
# | epoch 119 | perplexity 55.72
# | epoch 120 | perplexity 56.24
# | epoch 121 | perplexity 56.69
# | epoch 122 | perplexity 55.96
# | epoch 123 | perplexity 57.06
# | epoch 124 | perplexity 55.34
# | epoch 125 | perplexity 54.53
# | epoch 126 | perplexity 56.01
# | epoch 127 | perplexity 56.05
# | epoch 128 | perplexity 56.77
# | epoch 129 | perplexity 55.75
# | epoch 130 | perplexity 56.72
# | epoch 131 | perplexity 55.28
# | epoch 132 | perplexity 54.63
# | epoch 133 | perplexity 55.61
# | epoch 134 | perplexity 55.91
# | epoch 135 | perplexity 56.91
# | epoch 136 | perplexity 55.75
# | epoch 137 | perplexity 56.37
# | epoch 138 | perplexity 55.30
# | epoch 139 | perplexity 54.31
# | epoch 140 | perplexity 55.55
# | epoch 141 | perplexity 56.18
# | epoch 142 | perplexity 56.92
# | epoch 143 | perplexity 55.25
# | epoch 144 | perplexity 56.31
# | epoch 145 | perplexity 55.30
# | epoch 146 | perplexity 54.25
# | epoch 147 | perplexity 55.94
# | epoch 148 | perplexity 56.49
# | epoch 149 | perplexity 55.70
# | epoch 150 | perplexity 55.42
# | epoch 151 | perplexity 55.94
# | epoch 152 | perplexity 55.31
# | epoch 153 | perplexity 54.60
# | epoch 154 | perplexity 55.58
# | epoch 155 | perplexity 55.90
# | epoch 156 | perplexity 56.21
# | epoch 157 | perplexity 55.14
# | epoch 158 | perplexity 56.02
# | epoch 159 | perplexity 55.14
# | epoch 160 | perplexity 54.44
# | epoch 161 | perplexity 55.31
# | epoch 162 | perplexity 56.05
# | epoch 163 | perplexity 56.04
# | epoch 164 | perplexity 54.74
# | epoch 165 | perplexity 56.09
# | epoch 166 | perplexity 54.60
# | epoch 167 | perplexity 54.34
# | epoch 168 | perplexity 55.55
# | epoch 169 | perplexity 55.77
# | epoch 170 | perplexity 55.64
# | epoch 171 | perplexity 55.20
# | epoch 172 | perplexity 55.94
# | epoch 173 | perplexity 53.87
# | epoch 174 | perplexity 54.59
# | epoch 175 | perplexity 54.92
# | epoch 176 | perplexity 55.33
# | epoch 177 | perplexity 55.96
# | epoch 178 | perplexity 54.76
# | epoch 179 | perplexity 55.85
# | epoch 180 | perplexity 53.51
# | epoch 181 | perplexity 53.86
# | epoch 182 | perplexity 54.59
# | epoch 183 | perplexity 55.20
# | epoch 184 | perplexity 54.46
# | epoch 185 | perplexity 54.35
# | epoch 186 | perplexity 53.69
# | epoch 187 | perplexity 52.11
# | epoch 188 | perplexity 53.40
# | epoch 189 | perplexity 55.11
# | epoch 190 | perplexity 53.30
# | epoch 191 | perplexity 53.04
# | epoch 192 | perplexity 54.26
# | epoch 193 | perplexity 53.06
# | epoch 194 | perplexity 50.97
# | epoch 195 | perplexity 52.96
# | epoch 196 | perplexity 52.28
# | epoch 197 | perplexity 51.99
# | epoch 198 | perplexity 51.88
# | epoch 199 | perplexity 53.09
# | epoch 200 | perplexity 52.53
# | epoch 201 | perplexity 50.77
# | epoch 202 | perplexity 51.78
# | epoch 203 | perplexity 51.36
# | epoch 204 | perplexity 52.22
# | epoch 205 | perplexity 52.37
# | epoch 206 | perplexity 52.91
# | epoch 207 | perplexity 52.07
# | epoch 208 | perplexity 48.53
# | epoch 209 | perplexity 50.78
# | epoch 210 | perplexity 51.89
# | epoch 211 | perplexity 53.23
# | epoch 212 | perplexity 51.40
# | epoch 213 | perplexity 52.65
# | epoch 214 | perplexity 49.88
# | epoch 215 | perplexity 48.80
# | epoch 216 | perplexity 52.47
# | epoch 217 | perplexity 52.05
# | epoch 218 | perplexity 51.68
# | epoch 219 | perplexity 51.05
# | epoch 220 | perplexity 51.38
# | epoch 221 | perplexity 50.31
# | epoch 222 | perplexity 51.08
# | epoch 223 | perplexity 51.21
# | epoch 224 | perplexity 51.54
# | epoch 225 | perplexity 50.80
# | epoch 226 | perplexity 50.20
# | epoch 227 | perplexity 51.89
# | epoch 228 | perplexity 51.84
# | epoch 229 | perplexity 50.90
# | epoch 230 | perplexity 50.57
# | epoch 231 | perplexity 50.65
# | epoch 232 | perplexity 50.34
# | epoch 233 | perplexity 50.90
# | epoch 234 | perplexity 53.64
# | epoch 235 | perplexity 50.67
# | epoch 236 | perplexity 49.02
# | epoch 237 | perplexity 49.52
# | epoch 238 | perplexity 50.21
# | epoch 239 | perplexity 50.69
# | epoch 240 | perplexity 51.77
# | epoch 241 | perplexity 50.76
# | epoch 242 | perplexity 48.94
# | epoch 243 | perplexity 47.80
# | epoch 244 | perplexity 48.73
# | epoch 245 | perplexity 51.35
# | epoch 246 | perplexity 53.37
# | epoch 247 | perplexity 48.86
# | epoch 248 | perplexity 49.22
# | epoch 249 | perplexity 47.76
# | epoch 250 | perplexity 48.07
# | epoch 251 | perplexity 51.05
# | epoch 252 | perplexity 51.83
# | epoch 253 | perplexity 50.12
# | epoch 254 | perplexity 47.95
# | epoch 255 | perplexity 48.74
# | epoch 256 | perplexity 49.59
# | epoch 257 | perplexity 50.63
# | epoch 258 | perplexity 50.18
# | epoch 259 | perplexity 49.07
# | epoch 260 | perplexity 48.16
# | epoch 261 | perplexity 47.73
# | epoch 262 | perplexity 49.84
# | epoch 263 | perplexity 50.14
# | epoch 264 | perplexity 48.79
# | epoch 265 | perplexity 47.82
# | epoch 266 | perplexity 48.09
# | epoch 267 | perplexity 48.74
# | epoch 268 | perplexity 49.08
# | epoch 269 | perplexity 49.37
# | epoch 270 | perplexity 48.32
# | epoch 271 | perplexity 46.50
# | epoch 272 | perplexity 47.03
# | epoch 273 | perplexity 50.26
# | epoch 274 | perplexity 49.42
# | epoch 275 | perplexity 48.34
# | epoch 276 | perplexity 46.19
# | epoch 277 | perplexity 45.86
# | epoch 278 | perplexity 45.88
# | epoch 279 | perplexity 48.28
# | epoch 280 | perplexity 46.84
# | epoch 281 | perplexity 48.67
# | epoch 282 | perplexity 45.91
# | epoch 283 | perplexity 46.52
# | epoch 284 | perplexity 46.43
# | epoch 285 | perplexity 47.26
# | epoch 286 | perplexity 46.91
# | epoch 287 | perplexity 46.91
# | epoch 288 | perplexity 46.03
# | epoch 289 | perplexity 45.69
# | epoch 290 | perplexity 45.03
# | epoch 291 | perplexity 46.37
# | epoch 292 | perplexity 45.48
# | epoch 293 | perplexity 45.62
# | epoch 294 | perplexity 43.79
# | epoch 295 | perplexity 44.74
# | epoch 296 | perplexity 46.32
# | epoch 297 | perplexity 47.12
# | epoch 298 | perplexity 44.16
# | epoch 299 | perplexity 46.26
# | epoch 300 | perplexity 47.81
# | epoch 301 | perplexity 43.32
# | epoch 302 | perplexity 44.15
# | epoch 303 | perplexity 44.54
# | epoch 304 | perplexity 45.59
# | epoch 305 | perplexity 41.57
# | epoch 306 | perplexity 44.73
# | epoch 307 | perplexity 43.63
# | epoch 308 | perplexity 43.89
# | epoch 309 | perplexity 44.52
# | epoch 310 | perplexity 46.30
# | epoch 311 | perplexity 42.68
# | epoch 312 | perplexity 40.77
# | epoch 313 | perplexity 41.08
# | epoch 314 | perplexity 42.59
# | epoch 315 | perplexity 43.63
# | epoch 316 | perplexity 43.69
# | epoch 317 | perplexity 41.29
# | epoch 318 | perplexity 43.17
# | epoch 319 | perplexity 41.66
# | epoch 320 | perplexity 41.02
# | epoch 321 | perplexity 40.60
# | epoch 322 | perplexity 39.70
# | epoch 323 | perplexity 39.08
# | epoch 324 | perplexity 39.72
# | epoch 325 | perplexity 39.60
# | epoch 326 | perplexity 38.46
# | epoch 327 | perplexity 41.91
# | epoch 328 | perplexity 39.62
# | epoch 329 | perplexity 39.57
# | epoch 330 | perplexity 41.70
# | epoch 331 | perplexity 40.88
# | epoch 332 | perplexity 40.78
# | epoch 333 | perplexity 39.60
# | epoch 334 | perplexity 39.58
# | epoch 335 | perplexity 39.14
# | epoch 336 | perplexity 35.68
# | epoch 337 | perplexity 37.30
# | epoch 338 | perplexity 36.59
# | epoch 339 | perplexity 37.39
# | epoch 340 | perplexity 37.73
# | epoch 341 | perplexity 38.72
# | epoch 342 | perplexity 36.20
# | epoch 343 | perplexity 32.48
# | epoch 344 | perplexity 33.27
# | epoch 345 | perplexity 32.13
# | epoch 346 | perplexity 31.97
# | epoch 347 | perplexity 30.33
# | epoch 348 | perplexity 30.46
# | epoch 349 | perplexity 28.90
# | epoch 350 | perplexity 30.82
# | epoch 351 | perplexity 31.31
# | epoch 352 | perplexity 29.88
# | epoch 353 | perplexity 30.60
# | epoch 354 | perplexity 28.94
# | epoch 355 | perplexity 28.20
# | epoch 356 | perplexity 28.67
# | epoch 357 | perplexity 28.36
# | epoch 358 | perplexity 27.21
# | epoch 359 | perplexity 26.83
# | epoch 360 | perplexity 26.04
# | epoch 361 | perplexity 24.99
# | epoch 362 | perplexity 25.56
# | epoch 363 | perplexity 25.37
# | epoch 364 | perplexity 25.06
# | epoch 365 | perplexity 23.71
# | epoch 366 | perplexity 23.03
# | epoch 367 | perplexity 24.33
# | epoch 368 | perplexity 23.50
# | epoch 369 | perplexity 23.65
# | epoch 370 | perplexity 23.27
# | epoch 371 | perplexity 23.08
# | epoch 372 | perplexity 22.90
# | epoch 373 | perplexity 22.54
# | epoch 374 | perplexity 22.05
# | epoch 375 | perplexity 21.55
# | epoch 376 | perplexity 21.57
# | epoch 377 | perplexity 21.77
# | epoch 378 | perplexity 21.53
# | epoch 379 | perplexity 21.10
# | epoch 380 | perplexity 20.97
# | epoch 381 | perplexity 20.47
# | epoch 382 | perplexity 20.26
# | epoch 383 | perplexity 19.77
# | epoch 384 | perplexity 23.17
# | epoch 385 | perplexity 23.02
# | epoch 386 | perplexity 22.24
# | epoch 387 | perplexity 22.26
# | epoch 388 | perplexity 21.81
# | epoch 389 | perplexity 21.32
# | epoch 390 | perplexity 21.60
# | epoch 391 | perplexity 20.71
# | epoch 392 | perplexity 20.71
# | epoch 393 | perplexity 20.58
# | epoch 394 | perplexity 20.36
# | epoch 395 | perplexity 20.10
# | epoch 396 | perplexity 19.90
# | epoch 397 | perplexity 19.92
# | epoch 398 | perplexity 20.57
# | epoch 399 | perplexity 20.03
# | epoch 400 | perplexity 19.72
# | epoch 401 | perplexity 17.73
# | epoch 402 | perplexity 19.33
# | epoch 403 | perplexity 19.69
# | epoch 404 | perplexity 18.92
# | epoch 405 | perplexity 19.03
# | epoch 406 | perplexity 20.99
# | epoch 407 | perplexity 21.11
# | epoch 408 | perplexity 20.07
# | epoch 409 | perplexity 20.42
# | epoch 410 | perplexity 20.05
# | epoch 411 | perplexity 19.95
# | epoch 412 | perplexity 18.78
# | epoch 413 | perplexity 18.16
# | epoch 414 | perplexity 17.65
# | epoch 415 | perplexity 18.21
# | epoch 416 | perplexity 18.05
# | epoch 417 | perplexity 19.59
# | epoch 418 | perplexity 19.81
# | epoch 419 | perplexity 18.93
# | epoch 420 | perplexity 17.45
# | epoch 421 | perplexity 16.00
# | epoch 422 | perplexity 15.22
# | epoch 423 | perplexity 15.04
# | epoch 424 | perplexity 14.78
# | epoch 425 | perplexity 14.73
# | epoch 426 | perplexity 14.33
# | epoch 427 | perplexity 14.69
# | epoch 428 | perplexity 14.23
# | epoch 429 | perplexity 13.85
# | epoch 430 | perplexity 13.99
# | epoch 431 | perplexity 13.83
# | epoch 432 | perplexity 13.86
# | epoch 433 | perplexity 13.56
# | epoch 434 | perplexity 13.92
# | epoch 435 | perplexity 13.64
# | epoch 436 | perplexity 13.36
# | epoch 437 | perplexity 13.36
# | epoch 438 | perplexity 13.19
# | epoch 439 | perplexity 13.18
# | epoch 440 | perplexity 13.20
# | epoch 441 | perplexity 13.46
# | epoch 442 | perplexity 13.13
# | epoch 443 | perplexity 12.87
# | epoch 444 | perplexity 12.91
# | epoch 445 | perplexity 12.97
# | epoch 446 | perplexity 12.88
# | epoch 447 | perplexity 12.81
# | epoch 448 | perplexity 13.05
# | epoch 449 | perplexity 12.63
# | epoch 450 | perplexity 12.51
# | epoch 451 | perplexity 12.58
# | epoch 452 | perplexity 12.60
# | epoch 453 | perplexity 12.45
# | epoch 454 | perplexity 12.64
# | epoch 455 | perplexity 12.62
# | epoch 456 | perplexity 12.28
# | epoch 457 | perplexity 12.39
# | epoch 458 | perplexity 12.16
# | epoch 459 | perplexity 12.35
# | epoch 460 | perplexity 12.05
# | epoch 461 | perplexity 12.35
# | epoch 462 | perplexity 12.27
# | epoch 463 | perplexity 12.03
# | epoch 464 | perplexity 12.11
# | epoch 465 | perplexity 11.80
# | epoch 466 | perplexity 12.03
# | epoch 467 | perplexity 11.82
# | epoch 468 | perplexity 12.04
# | epoch 469 | perplexity 11.97
# | epoch 470 | perplexity 11.80
# | epoch 471 | perplexity 11.78
# | epoch 472 | perplexity 11.58
# | epoch 473 | perplexity 11.74
# | epoch 474 | perplexity 11.62
# | epoch 475 | perplexity 11.70
# | epoch 476 | perplexity 11.69
# | epoch 477 | perplexity 11.41
# | epoch 478 | perplexity 11.53
# | epoch 479 | perplexity 11.19
# | epoch 480 | perplexity 11.46
# | epoch 481 | perplexity 11.31
# | epoch 482 | perplexity 11.43
# | epoch 483 | perplexity 11.45
# | epoch 484 | perplexity 11.24
# | epoch 485 | perplexity 11.12
# | epoch 486 | perplexity 10.95
# | epoch 487 | perplexity 11.21
# | epoch 488 | perplexity 11.15
# | epoch 489 | perplexity 11.04
# | epoch 490 | perplexity 11.15
# | epoch 491 | perplexity 10.95
# | epoch 492 | perplexity 10.84
# | epoch 493 | perplexity 10.73
# | epoch 494 | perplexity 10.89
# | epoch 495 | perplexity 10.68
# | epoch 496 | perplexity 10.82
# | epoch 497 | perplexity 10.64
# | epoch 498 | perplexity 10.67
# | epoch 499 | perplexity 10.57
# | epoch 500 | perplexity 10.34
# | epoch 501 | perplexity 10.68
# | epoch 502 | perplexity 10.28
# | epoch 503 | perplexity 10.50
# | epoch 504 | perplexity 10.49
# | epoch 505 | perplexity 10.23
# | epoch 506 | perplexity 10.23
# | epoch 507 | perplexity 9.99
# | epoch 508 | perplexity 10.29
# | epoch 509 | perplexity 10.02
# | epoch 510 | perplexity 10.11
# | epoch 511 | perplexity 10.17
# | epoch 512 | perplexity 9.97
# | epoch 513 | perplexity 9.88
# | epoch 514 | perplexity 9.87
# | epoch 515 | perplexity 9.96
# | epoch 516 | perplexity 9.68
# | epoch 517 | perplexity 9.84
# | epoch 518 | perplexity 9.86
# | epoch 519 | perplexity 9.63
# | epoch 520 | perplexity 9.64
# | epoch 521 | perplexity 9.63
# | epoch 522 | perplexity 9.67
# | epoch 523 | perplexity 9.31
# | epoch 524 | perplexity 9.63
# | epoch 525 | perplexity 9.62
# | epoch 526 | perplexity 9.34
# | epoch 527 | perplexity 9.38
# | epoch 528 | perplexity 9.31
# | epoch 529 | perplexity 9.41
# | epoch 530 | perplexity 9.18
# | epoch 531 | perplexity 9.36
# | epoch 532 | perplexity 9.29
# | epoch 533 | perplexity 9.13
# | epoch 534 | perplexity 9.17
# | epoch 535 | perplexity 9.05
# | epoch 536 | perplexity 9.19
# | epoch 537 | perplexity 8.95
# | epoch 538 | perplexity 9.14
# | epoch 539 | perplexity 8.99
# | epoch 540 | perplexity 8.97
# | epoch 541 | perplexity 8.89
# | epoch 542 | perplexity 8.87
# | epoch 543 | perplexity 8.99
# | epoch 544 | perplexity 8.70
# | epoch 545 | perplexity 8.95
# | epoch 546 | perplexity 8.80
# | epoch 547 | perplexity 8.76
# | epoch 548 | perplexity 8.79
# | epoch 549 | perplexity 8.65
# | epoch 550 | perplexity 8.76
# | epoch 551 | perplexity 8.57
# | epoch 552 | perplexity 8.73
# | epoch 553 | perplexity 8.61
# | epoch 554 | perplexity 8.57
# | epoch 555 | perplexity 8.60
# | epoch 556 | perplexity 8.52
# | epoch 557 | perplexity 8.56
# | epoch 558 | perplexity 8.50
# | epoch 559 | perplexity 8.58
# | epoch 560 | perplexity 8.43
# | epoch 561 | perplexity 8.50
# | epoch 562 | perplexity 8.35
# | epoch 563 | perplexity 8.35
# | epoch 564 | perplexity 8.43
# | epoch 565 | perplexity 8.37
# | epoch 566 | perplexity 8.43
# | epoch 567 | perplexity 8.27
# | epoch 568 | perplexity 8.33
# | epoch 569 | perplexity 8.24
# | epoch 570 | perplexity 8.27
# | epoch 571 | perplexity 8.29
# | epoch 572 | perplexity 8.35
# | epoch 573 | perplexity 8.25
# | epoch 574 | perplexity 8.15
# | epoch 575 | perplexity 8.21
# | epoch 576 | perplexity 8.12
# | epoch 577 | perplexity 8.18
# | epoch 578 | perplexity 8.16
# | epoch 579 | perplexity 8.18
# | epoch 580 | perplexity 8.14
# | epoch 581 | perplexity 8.04
# | epoch 582 | perplexity 8.15
# | epoch 583 | perplexity 8.03
# | epoch 584 | perplexity 8.09
# | epoch 585 | perplexity 8.09
# | epoch 586 | perplexity 8.02
# | epoch 587 | perplexity 8.02
# | epoch 588 | perplexity 7.97
# | epoch 589 | perplexity 8.05
# | epoch 590 | perplexity 7.95
# | epoch 591 | perplexity 7.97
# | epoch 592 | perplexity 7.98
# | epoch 593 | perplexity 7.95
# | epoch 594 | perplexity 7.96
# | epoch 595 | perplexity 7.89
# | epoch 596 | perplexity 7.90
# | epoch 597 | perplexity 7.85
# | epoch 598 | perplexity 7.88
# | epoch 599 | perplexity 7.93
# | epoch 600 | perplexity 7.91
# | epoch 601 | perplexity 7.87
# | epoch 602 | perplexity 7.85
# | epoch 603 | perplexity 7.83
# | epoch 604 | perplexity 7.75
# | epoch 605 | perplexity 7.83
# | epoch 606 | perplexity 7.81
# | epoch 607 | perplexity 7.80
# | epoch 608 | perplexity 7.76
# | epoch 609 | perplexity 7.80
# | epoch 610 | perplexity 7.78
# | epoch 611 | perplexity 7.73
# | epoch 612 | perplexity 7.81
# | epoch 613 | perplexity 7.70
# | epoch 614 | perplexity 7.73
# | epoch 615 | perplexity 7.83
# | epoch 616 | perplexity 7.66
# | epoch 617 | perplexity 7.65
# | epoch 618 | perplexity 7.65
# | epoch 619 | perplexity 7.72
# | epoch 620 | perplexity 7.60
# | epoch 621 | perplexity 7.75
# | epoch 622 | perplexity 7.70
# | epoch 623 | perplexity 7.63
# | epoch 624 | perplexity 7.57
# | epoch 625 | perplexity 7.61
# | epoch 626 | perplexity 7.65
# | epoch 627 | perplexity 7.59
# | epoch 628 | perplexity 7.60
# | epoch 629 | perplexity 7.67
# | epoch 630 | perplexity 7.56
# | epoch 631 | perplexity 7.54
# | epoch 632 | perplexity 7.60
# | epoch 633 | perplexity 7.60
# | epoch 634 | perplexity 7.50
# | epoch 635 | perplexity 7.54
# | epoch 636 | perplexity 7.63
# | epoch 637 | perplexity 7.51
# | epoch 638 | perplexity 7.44
# | epoch 639 | perplexity 7.56
# | epoch 640 | perplexity 7.55
# | epoch 641 | perplexity 7.44
# | epoch 642 | perplexity 7.58
# | epoch 643 | perplexity 7.51
# | epoch 644 | perplexity 7.48
# | epoch 645 | perplexity 7.44
# | epoch 646 | perplexity 7.45
# | epoch 647 | perplexity 7.50
# | epoch 648 | perplexity 7.40
# | epoch 649 | perplexity 7.47
# | epoch 650 | perplexity 7.51
# | epoch 651 | perplexity 7.46
# | epoch 652 | perplexity 7.37
# | epoch 653 | perplexity 7.41
# | epoch 654 | perplexity 7.44
# | epoch 655 | perplexity 7.35
# | epoch 656 | perplexity 7.51
# | epoch 657 | perplexity 7.48
# | epoch 658 | perplexity 7.36
# | epoch 659 | perplexity 7.33
# | epoch 660 | perplexity 7.38
# | epoch 661 | perplexity 7.38
# | epoch 662 | perplexity 7.36
# | epoch 663 | perplexity 7.45
# | epoch 664 | perplexity 7.31
# | epoch 665 | perplexity 7.31
# | epoch 666 | perplexity 7.31
# | epoch 667 | perplexity 7.40
# | epoch 668 | perplexity 7.36
# | epoch 669 | perplexity 7.29
# | epoch 670 | perplexity 7.30
# | epoch 671 | perplexity 7.23
# | epoch 672 | perplexity 7.35
# | epoch 673 | perplexity 7.27
# | epoch 674 | perplexity 7.34
# | epoch 675 | perplexity 7.21
# | epoch 676 | perplexity 7.25
# | epoch 677 | perplexity 7.21
# | epoch 678 | perplexity 7.31
# | epoch 679 | perplexity 7.28
# | epoch 680 | perplexity 7.17
# | epoch 681 | perplexity 7.25
# | epoch 682 | perplexity 7.15
# | epoch 683 | perplexity 7.21
# | epoch 684 | perplexity 7.36
# | epoch 685 | perplexity 7.26
# | epoch 686 | perplexity 7.28
# | epoch 687 | perplexity 7.09
# | epoch 688 | perplexity 7.17
# | epoch 689 | perplexity 7.16
# | epoch 690 | perplexity 7.26
# | epoch 691 | perplexity 7.19
# | epoch 692 | perplexity 7.16
# | epoch 693 | perplexity 7.20
# | epoch 694 | perplexity 7.04
# | epoch 695 | perplexity 7.21
# | epoch 696 | perplexity 7.23
# | epoch 697 | perplexity 7.19
# | epoch 698 | perplexity 7.24
# | epoch 699 | perplexity 7.12
# | epoch 700 | perplexity 7.09
# | epoch 701 | perplexity 7.09
# | epoch 702 | perplexity 7.22
# | epoch 703 | perplexity 7.11
# | epoch 704 | perplexity 7.29
# | epoch 705 | perplexity 7.20
# | epoch 706 | perplexity 7.16
# | epoch 707 | perplexity 7.23
# | epoch 708 | perplexity 7.19
# | epoch 709 | perplexity 7.24
# | epoch 710 | perplexity 7.34
# | epoch 711 | perplexity 7.21
# | epoch 712 | perplexity 7.16
# | epoch 713 | perplexity 7.28
# | epoch 714 | perplexity 7.25
# | epoch 715 | perplexity 7.17
# | epoch 716 | perplexity 7.28
# | epoch 717 | perplexity 7.24
# | epoch 718 | perplexity 7.20
# | epoch 719 | perplexity 7.32
# | epoch 720 | perplexity 7.27
# | epoch 721 | perplexity 7.21
# | epoch 722 | perplexity 7.11
# | epoch 723 | perplexity 7.28
# | epoch 724 | perplexity 7.18
# | epoch 725 | perplexity 7.31
# | epoch 726 | perplexity 7.40
# | epoch 727 | perplexity 7.23
# | epoch 728 | perplexity 7.23
# | epoch 729 | perplexity 7.20
# | epoch 730 | perplexity 7.31
# | epoch 731 | perplexity 7.22
# | epoch 732 | perplexity 7.28
# | epoch 733 | perplexity 7.28
# | epoch 734 | perplexity 7.20
# | epoch 735 | perplexity 7.15
# | epoch 736 | perplexity 7.24
# | epoch 737 | perplexity 7.24
# | epoch 738 | perplexity 7.16
# | epoch 739 | perplexity 7.26
# | epoch 740 | perplexity 7.20
# | epoch 741 | perplexity 7.15
# | epoch 742 | perplexity 7.18
# | epoch 743 | perplexity 7.14
# | epoch 744 | perplexity 7.15
# | epoch 745 | perplexity 7.18
# | epoch 746 | perplexity 7.15
# | epoch 747 | perplexity 7.10
# | epoch 748 | perplexity 7.15
# | epoch 749 | perplexity 7.14
# | epoch 750 | perplexity 7.12
# | epoch 751 | perplexity 7.19
# | epoch 752 | perplexity 7.03
# | epoch 753 | perplexity 7.09
# | epoch 754 | perplexity 7.08
# | epoch 755 | perplexity 7.12
# | epoch 756 | perplexity 7.17
# | epoch 757 | perplexity 7.02
# | epoch 758 | perplexity 7.04
# | epoch 759 | perplexity 7.01
# | epoch 760 | perplexity 7.13
# | epoch 761 | perplexity 7.09
# | epoch 762 | perplexity 6.94
# | epoch 763 | perplexity 7.01
# | epoch 764 | perplexity 6.94
# | epoch 765 | perplexity 6.98
# | epoch 766 | perplexity 7.12
# | epoch 767 | perplexity 7.25
# | epoch 768 | perplexity 7.03
# | epoch 769 | perplexity 6.87
# | epoch 770 | perplexity 6.92
# | epoch 771 | perplexity 6.92
# | epoch 772 | perplexity 7.05
# | epoch 773 | perplexity 7.03
# | epoch 774 | perplexity 6.97
# | epoch 775 | perplexity 6.85
# | epoch 776 | perplexity 6.84
# | epoch 777 | perplexity 7.01
# | epoch 778 | perplexity 7.07
# | epoch 779 | perplexity 7.00
# | epoch 780 | perplexity 6.95
# | epoch 781 | perplexity 6.93
# | epoch 782 | perplexity 6.90
# | epoch 783 | perplexity 6.94
# | epoch 784 | perplexity 6.91
# | epoch 785 | perplexity 6.90
# | epoch 786 | perplexity 6.78
# | epoch 787 | perplexity 6.83
# | epoch 788 | perplexity 6.86
# | epoch 789 | perplexity 7.07
# | epoch 790 | perplexity 7.19
# | epoch 791 | perplexity 6.97
# | epoch 792 | perplexity 7.09
# | epoch 793 | perplexity 7.03
# | epoch 794 | perplexity 6.87
# | epoch 795 | perplexity 6.91
# | epoch 796 | perplexity 7.06
# | epoch 797 | perplexity 6.97
# | epoch 798 | perplexity 6.97
# | epoch 799 | perplexity 7.04
# | epoch 800 | perplexity 6.88
# | epoch 801 | perplexity 6.93
# | epoch 802 | perplexity 7.07
# | epoch 803 | perplexity 7.01
# | epoch 804 | perplexity 6.89
# | epoch 805 | perplexity 6.79
# | epoch 806 | perplexity 6.78
# | epoch 807 | perplexity 6.82
# | epoch 808 | perplexity 6.96
# | epoch 809 | perplexity 6.80
# | epoch 810 | perplexity 6.91
# | epoch 811 | perplexity 6.71
# | epoch 812 | perplexity 6.61
# | epoch 813 | perplexity 6.78
# | epoch 814 | perplexity 6.70
# | epoch 815 | perplexity 6.77
# | epoch 816 | perplexity 6.70
# | epoch 817 | perplexity 6.53
# | epoch 818 | perplexity 6.55
# | epoch 819 | perplexity 6.65
# | epoch 820 | perplexity 6.69
# | epoch 821 | perplexity 6.69
# | epoch 822 | perplexity 6.81
# | epoch 823 | perplexity 6.68
# | epoch 824 | perplexity 6.56
# | epoch 825 | perplexity 6.89
# | epoch 826 | perplexity 6.78
# | epoch 827 | perplexity 6.92
# | epoch 828 | perplexity 6.72
# | epoch 829 | perplexity 6.62
# | epoch 830 | perplexity 6.65
# | epoch 831 | perplexity 6.78
# | epoch 832 | perplexity 6.90
# | epoch 833 | perplexity 7.11
# | epoch 834 | perplexity 6.78
# | epoch 835 | perplexity 6.78
# | epoch 836 | perplexity 6.86
# | epoch 837 | perplexity 6.97
# | epoch 838 | perplexity 6.86
# | epoch 839 | perplexity 6.74
# | epoch 840 | perplexity 10.63
# | epoch 841 | perplexity 12.10
# | epoch 842 | perplexity 12.92
# | epoch 843 | perplexity 11.84
# | epoch 844 | perplexity 11.66
# | epoch 845 | perplexity 11.46
# | epoch 846 | perplexity 10.81
# | epoch 847 | perplexity 12.46
# | epoch 848 | perplexity 14.52
# | epoch 849 | perplexity 17.64
# | epoch 850 | perplexity 16.99
# | epoch 851 | perplexity 11.53
# | epoch 852 | perplexity 12.01
# | epoch 853 | perplexity 11.66
# | epoch 854 | perplexity 11.94
# | epoch 855 | perplexity 15.11
# | epoch 856 | perplexity 15.71
# | epoch 857 | perplexity 17.29
# | epoch 858 | perplexity 26.21
# | epoch 859 | perplexity 75.73
# | epoch 860 | perplexity 60.38
# | epoch 861 | perplexity 58.41
# | epoch 862 | perplexity 56.40
# | epoch 863 | perplexity 54.98
# | epoch 864 | perplexity 56.17
# | epoch 865 | perplexity 56.22
# | epoch 866 | perplexity 54.77
# | epoch 867 | perplexity 51.55
# | epoch 868 | perplexity 53.96
# | epoch 869 | perplexity 54.95
# | epoch 870 | perplexity 54.85
# | epoch 871 | perplexity 52.63
# | epoch 872 | perplexity 55.28
# | epoch 873 | perplexity 54.58
# | epoch 874 | perplexity 50.33
# | epoch 875 | perplexity 52.85
# | epoch 876 | perplexity 54.80
# | epoch 877 | perplexity 51.41
# | epoch 878 | perplexity 51.14
# | epoch 879 | perplexity 51.54
# | epoch 880 | perplexity 51.74
# | epoch 881 | perplexity 49.31
# | epoch 882 | perplexity 51.62
# | epoch 883 | perplexity 51.84
# | epoch 884 | perplexity 50.43
# | epoch 885 | perplexity 50.44
# | epoch 886 | perplexity 50.72
# | epoch 887 | perplexity 49.50
# | epoch 888 | perplexity 47.40
# | epoch 889 | perplexity 47.96
# | epoch 890 | perplexity 50.27
# | epoch 891 | perplexity 48.56
# | epoch 892 | perplexity 48.95
# | epoch 893 | perplexity 47.34
# | epoch 894 | perplexity 45.93
# | epoch 895 | perplexity 43.20
# | epoch 896 | perplexity 45.73
# | epoch 897 | perplexity 46.20
# | epoch 898 | perplexity 45.23
# | epoch 899 | perplexity 42.53
# | epoch 900 | perplexity 44.33
# | epoch 901 | perplexity 45.94
# | epoch 902 | perplexity 41.20
# | epoch 903 | perplexity 45.39
# | epoch 904 | perplexity 43.86
# | epoch 905 | perplexity 41.12
# | epoch 906 | perplexity 43.33
# | epoch 907 | perplexity 43.24
# | epoch 908 | perplexity 44.65
# | epoch 909 | perplexity 34.75
# | epoch 910 | perplexity 34.94
# | epoch 911 | perplexity 37.39
# | epoch 912 | perplexity 35.85
# | epoch 913 | perplexity 41.77
# | epoch 914 | perplexity 36.74
# | epoch 915 | perplexity 32.41
# | epoch 916 | perplexity 32.63
# | epoch 917 | perplexity 35.70
# | epoch 918 | perplexity 29.08
# | epoch 919 | perplexity 27.60
# | epoch 920 | perplexity 26.39
# | epoch 921 | perplexity 27.20
# | epoch 922 | perplexity 25.74
# | epoch 923 | perplexity 21.44
# | epoch 924 | perplexity 21.67
# | epoch 925 | perplexity 20.11
# | epoch 926 | perplexity 19.39
# | epoch 927 | perplexity 19.05
# | epoch 928 | perplexity 18.33
# | epoch 929 | perplexity 17.66
# | epoch 930 | perplexity 18.25
# | epoch 931 | perplexity 19.89
# | epoch 932 | perplexity 21.76
# | epoch 933 | perplexity 20.28
# | epoch 934 | perplexity 19.51
# | epoch 935 | perplexity 21.04
# | epoch 936 | perplexity 19.41
# | epoch 937 | perplexity 19.56
# | epoch 938 | perplexity 19.42
# | epoch 939 | perplexity 17.90
# | epoch 940 | perplexity 17.20
# | epoch 941 | perplexity 16.86
# | epoch 942 | perplexity 17.79
# | epoch 943 | perplexity 17.33
# | epoch 944 | perplexity 16.56
# | epoch 945 | perplexity 14.10
# | epoch 946 | perplexity 12.75
# | epoch 947 | perplexity 12.49
# | epoch 948 | perplexity 12.29
# | epoch 949 | perplexity 11.83
# | epoch 950 | perplexity 11.65
# | epoch 951 | perplexity 11.70
# | epoch 952 | perplexity 11.54
# | epoch 953 | perplexity 11.48
# | epoch 954 | perplexity 11.14
# | epoch 955 | perplexity 11.35
# | epoch 956 | perplexity 11.13
# | epoch 957 | perplexity 10.82
# | epoch 958 | perplexity 11.12
# | epoch 959 | perplexity 10.94
# | epoch 960 | perplexity 10.74
# | epoch 961 | perplexity 10.76
# | epoch 962 | perplexity 10.97
# | epoch 963 | perplexity 10.67
# | epoch 964 | perplexity 10.54
# | epoch 965 | perplexity 10.75
# | epoch 966 | perplexity 10.72
# | epoch 967 | perplexity 10.48
# | epoch 968 | perplexity 10.50
# | epoch 969 | perplexity 10.70
# | epoch 970 | perplexity 10.35
# | epoch 971 | perplexity 10.33
# | epoch 972 | perplexity 10.63
# | epoch 973 | perplexity 10.56
# | epoch 974 | perplexity 10.32
# | epoch 975 | perplexity 10.32
# | epoch 976 | perplexity 10.35
# | epoch 977 | perplexity 10.25
# | epoch 978 | perplexity 10.24
# | epoch 979 | perplexity 10.38
# | epoch 980 | perplexity 10.29
# | epoch 981 | perplexity 10.12
# | epoch 982 | perplexity 10.31
# | epoch 983 | perplexity 10.31
# | epoch 984 | perplexity 10.14
# | epoch 985 | perplexity 10.07
# | epoch 986 | perplexity 10.23
# | epoch 987 | perplexity 10.13
# | epoch 988 | perplexity 10.15
# | epoch 989 | perplexity 10.26
# | epoch 990 | perplexity 10.15
# | epoch 991 | perplexity 9.94
# | epoch 992 | perplexity 9.95
# | epoch 993 | perplexity 10.18
# | epoch 994 | perplexity 10.11
# | epoch 995 | perplexity 10.03
# | epoch 996 | perplexity 10.10
# | epoch 997 | perplexity 10.06
# | epoch 998 | perplexity 10.01
# | epoch 999 | perplexity 10.24
# | epoch 1000 | perplexity 10.12
